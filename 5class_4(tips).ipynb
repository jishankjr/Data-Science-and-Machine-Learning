# %%
# Importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
## Load Datasets

data = sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
data.size
# Out:
# 1708

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
data.smoker.value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
data.time.value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
## Split X and y

# %%
X = data.drop('total_bill', axis=1)

# %%
y = data['total_bill']

# %%
X
# Out:
#       tip     sex smoker   day    time  size
# 0    1.01  Female     No   Sun  Dinner     2
# 1    1.66    Male     No   Sun  Dinner     3
# 2    3.50    Male     No   Sun  Dinner     3
# 3    3.31    Male     No   Sun  Dinner     2
# 4    3.61  Female     No   Sun  Dinner     4
# ..    ...     ...    ...   ...     ...   ...
# 239  5.92    Male     No   Sat  Dinner     3
# 240  2.00  Female    Yes   Sat  Dinner     2
# 241  2.00    Male    Yes   Sat  Dinner     2
# 242  1.75    Male     No   Sat  Dinner     2
# 243  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
y
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#        tip     sex smoker   day    time  size
# 92    1.00  Female    Yes   Fri  Dinner     2
# 81    3.40    Male     No  Thur   Lunch     2
# 170  10.00    Male    Yes   Sat  Dinner     3
# 213   2.50  Female    Yes   Sat  Dinner     2
# 200   4.00    Male    Yes  Thur   Lunch     3
# ..     ...     ...    ...   ...     ...   ...
# 232   3.39    Male     No   Sat  Dinner     2
# 220   2.20    Male    Yes   Fri   Lunch     2
# 206   3.41    Male    Yes   Sat  Dinner     3
# 20    4.08    Male     No   Sat  Dinner     2
# 27    2.00    Male     No   Sat  Dinner     2
#
# [170 rows x 6 columns]

# %%
day = pd.get_dummies(X_train['day'])
X_train.drop("day", axis=1, inplace=True)
X_train = pd.concat([X_train, day], axis = 1)

# %%
sex = pd.get_dummies(X_train['sex'])
X_train.drop("sex", axis=1, inplace=True)
X_train = pd.concat([X_train, sex], axis=1)

# %%
time = pd.get_dummies(X_train['time'])
X_train.drop("time", axis=1, inplace=True)
X_train = pd.concat([X_train, time], axis=1)

# %%
smoker = pd.get_dummies(X_train['smoker'])
X_train.drop("smoker", axis=1, inplace=True)
X_train = pd.concat([X_train, smoker], axis=1)

# %%
X_train
# Out:
#        tip  size   Thur    Fri    Sat    Sun   Male  Female  Lunch  Dinner  \
# 92    1.00     2  False   True  False  False  False    True  False    True
# 81    3.40     2   True  False  False  False   True   False   True   False
# 170  10.00     3  False  False   True  False   True   False  False    True
# 213   2.50     2  False  False   True  False  False    True  False    True
# 200   4.00     3   True  False  False  False   True   False   True   False
# ..     ...   ...    ...    ...    ...    ...    ...     ...    ...     ...
# 232   3.39     2  False  False   True  False   True   False  False    True
# 220   2.20     2  False   True  False  False   True   False   True   False
# 206   3.41     3  False  False   True  False   True   False  False    True
# 20    4.08     2  False  False   True  False   True   False  False    True
# 27    2.00     2  False  False   True  False   True   False  False    True
#
#        Yes     No
# 92    True  False
# 81   False   True
# 170   True  False
# 213   True  False
# 200   True  False
# ..     ...    ...
# 232  False   True
# 220   True  False
# 206   True  False
# 20   False   True
# 27   False   True
#
# [170 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
day = pd.get_dummies(X_test['day'])
X_test.drop("day", axis=1, inplace=True)
X_test = pd.concat([X_test, day], axis=1)

sex = pd.get_dummies(X_test['sex'])
X_test.drop("sex", axis=1, inplace=True)
X_test = pd.concat([X_test, sex], axis=1)

time = pd.get_dummies(X_test['time'])
X_test.drop("time", axis=1, inplace=True)
X_test = pd.concat([X_test, time], axis=1)

smoker = pd.get_dummies(X_test['smoker'])
X_test.drop("smoker", axis=1, inplace=True)
X_test = pd.concat([X_test, smoker], axis=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([14.10663504, 16.33495556, 21.80025848, 21.43830461, 32.70399499,
#        26.49447364, 14.91039773, 17.76388867, 17.18812361, 15.38812484,
#        12.44781748, 24.79199495, 14.87105427, 15.60250328, 14.45621732,
#        17.3676278 , 12.06163308, 14.07876726, 22.90630506, 11.98130708,
#        12.95915402, 19.09182233, 10.56576484, 16.28659651, 25.05519549,
#        14.94031509, 38.31460978, 13.29486003, 14.79072827, 15.62299455,
#        14.54477436, 16.52874653, 44.87593877, 14.81859605, 22.86746603,
#        20.090108  , 17.21403482, 15.81678552, 16.97264632, 12.06163308,
#        17.03853679, 24.47467009, 15.87662025, 13.53701005, 35.22839492,
#        13.62676215, 23.45291428, 16.52874653, 16.9746959 , 11.10427741,
#        12.00841335, 14.07066193, 22.12239783, 12.93043172, 25.27506242,
#        16.13892488, 10.95469058, 18.56637198, 28.15936664, 19.03357413,
#        23.17688212, 19.13803787, 13.17314099, 24.40954982, 20.08405225,
#        26.44921617,  9.81783072, 24.92548014, 16.30708778, 23.5977748 ,
#        18.808522  , 14.03131847, 26.42134838, 28.53296095])

# %%
from sklearn import metrics

# %%
print(np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# 6.164971729323212

# %%
data.total_bill.mean()
# Out:
# np.float64(19.78594262295082)

# %%
plt.scatter(y_test, predictions)
